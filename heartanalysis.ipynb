# %%
import pandas as pd
df=pd.read_csv('heart2.csv')

# %%
df
# Out:
#      Unnamed: 0   age  sex   cp  trestbps   chol  fbs  restecg  thalach  \
# 0             0  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0
# 1             1  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0
# 2             2  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0
# 3             3  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0
# 4             4  56.0  1.0  2.0     120.0  236.0  0.0      0.0    178.0
# ..          ...   ...  ...  ...       ...    ...  ...      ...      ...
# 297         297  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0
# 298         298  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0
# 299         299  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0
# 300         300  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0
# 301         301  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0
#
#      exang  oldpeak  slope   ca thal  num
# 0      1.0      1.5    2.0  3.0  3.0    2
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(df['age'],df['trestbps'])
plt.show()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
#        'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %%
df1=df[['age','trestbps','chol','restecg']]

# %%
import seaborn as sns
sns.pairplot(df1)

# %%
sns.countplot(x='sex',data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='age',hue='sex',data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
sns.boxplot(x="sex", y="chol", data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='chol'>

# %%
sns.swarmplot(x="sex", y="chol", data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='chol'>

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
#        'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %%
sns.swarmplot(x="cp", y="chol", data=df)
# Out:
# <AxesSubplot:xlabel='cp', ylabel='chol'>

# %%
sns.swarmplot(x="num", y="chol", data=df)
# Out:
# C:\Users\ICTAcademy\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 23.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='num', ylabel='chol'>
